# %%
import json
import pandas as pd

# %%
# Load the annotation data
with open('channel_islands_camera_traps.json', 'r') as f:
    lila = json.load(f)

# %% [markdown]
# ### Preprocess Lila Dataset
# 1. Non-correct-bbox which is too large(>0.95) or no bounding box:
#    - There are 115197 annotations
# 2. We don't want categories(id) empty(0), human(1), bird(5), other(6):
#    - There are 16893 annotations

# %%
image_lookup = {img['id']: img for img in lila['images']}
no_bbox_annotations_all = []

for annotation in lila['annotations']:
    image_id = annotation['image_id']
    image = image_lookup.get(image_id)
    if image is not None:
        if 'bbox' in annotation:
            bbox = annotation['bbox']
            if bbox:
                width, height = image['width'], image['height']
                if bbox[2] >= 0.95 * width and bbox[3] >= 0.95 * height:
                    no_bbox_annotations_all.append(annotation)
            else:
                no_bbox_annotations_all.append(annotation)
        else:
            no_bbox_annotations_all.append(annotation)

print(f"Number of annotations without bounding boxes: {len(no_bbox_annotations_all)}")
# Out:
# Number of annotations without bounding boxes: 115197

# %%
image_lookup = {img['id']: img for img in lila['images']}
legit_anns = []
legit_images = []
for annotation in lila['annotations']:
    image_id = annotation['image_id']
    image = image_lookup.get(image_id)
    if image is not None:
        if ((bbox := annotation.get('bbox')) is not None) and (annotation.get('category_id') not in {0, 1, 5, 6}):
            width, height = image['width'], image['height']
            if bbox[2] < 0.95 * width or bbox[3] < 0.95 * height:
                # print(annotation)
                legit_anns.append(annotation)
                # print(image)
                legit_images.append(image)

# %%
len(legit_anns), len(legit_images)
# Out:
# (132090, 132090)

# %%
print(f'There are {len(legit_anns) - len(no_bbox_annotations_all)} in categories(id) empty(0), human(1), bird(5), other(6)' )
# Out:
# There are 16893 in categories(id) empty(0), human(1), bird(5), other(6)

# %%
len(lila['annotations']) - 132090
# Out:
# 132231

# %%
print(len(lila['annotations']))
# Out:
# 264321

# %%
[{'id': 0, 'name': 'empty'},
  {'id': 1, 'name': 'human'},
  {'id': 2, 'name': 'fox'},
  {'id': 3, 'name': 'skunk'},
  {'id': 4, 'name': 'rodent'},
  {'id': 5, 'name': 'bird'},
  {'id': 6, 'name': 'other'}]
# Out:
# [{'id': 0, 'name': 'empty'},
#  {'id': 1, 'name': 'human'},
#  {'id': 2, 'name': 'fox'},
#  {'id': 3, 'name': 'skunk'},
#  {'id': 4, 'name': 'rodent'},
#  {'id': 5, 'name': 'bird'},
#  {'id': 6, 'name': 'other'}]

# %%
df = pd.DataFrame(lila['annotations'])

counts = df.groupby(['category_id']).size().reset_index(name='counts')

# mapping the category_id to the category name
counts['category_name'] = counts['category_id'].map({0: 'empty', 1: 'human', 2: 'fox', 3: 'skunk', 4: 'rodent', 5: 'bird', 6: 'other'})
counts
# Out:
#    category_id  counts category_name
# 0            0  114949         empty
# 1            1    5981         human
# 2            2   48150           fox
# 3            3    1071         skunk
# 4            4   82912        rodent
# 5            5   11099          bird
# 6            6     159         other

# %%
df = pd.DataFrame(legit_anns)

counts = df.groupby(['category_id']).size().reset_index(name='counts')

# mapping the category_id to the category name
counts['category_name'] = counts['category_id'].map({0: 'empty', 1: 'human', 2: 'fox', 3: 'skunk', 4: 'rodent', 5: 'bird', 6: 'other'})
counts
# Out:
#    category_id  counts category_name
# 0            2   48120           fox
# 1            3    1071         skunk
# 2            4   82899        rodent

# %%
len(legit_anns), len(legit_images)
# Out:
# (132090, 132090)

# %%
for img in legit_images:
    img['original_relative_path'] = img['file_name']

# %% [markdown]
# ### Animl Dataset

# %%
with open('14f460fffd7dc41f889093f6a1a1812a_coco.json', 'r') as f:
    animl = json.load(f)

# %%
animl_map = {animl['categories'][i]['id']:animl['categories'][i]['name'] for i in range(len(animl['categories']))}

# %%
df = pd.DataFrame(animl['annotations'])

counts = df.groupby(['category_id']).size().reset_index(name='counts')

# mapping the category_id to the category name
counts['category_name'] = counts['category_id'].map(animl_map)
counts
# Out:
#    category_id  counts category_name
# 0            0       3         empty
# 1            5   10836           fox
# 2            8       3        animal
# 3            9    6791        lizard
# 4           15    1216         skunk
# 5           19   16852        rodent
# 6           20   14110          bird
# 7           21    2592     scrub jay
# 8           23       1         mouse

# %%
image_lookup = {img['id']: img for img in animl['images']}
legit_anns_animl = []
legit_images_animl = []
for annotation in animl['annotations']:
    image_id = annotation['image_id']
    image = image_lookup.get(image_id)
    if image is not None:
        if ((bbox := annotation.get('bbox')) is not None) and (annotation.get('category_id') not in {0, 8, 23}):
            width, height = image['width'], image['height']
            if bbox[2] < 0.95 * width or bbox[3] < 0.95 * height:
                # print(annotation)
                legit_anns_animl.append(annotation)
                # print(image)
                legit_images_animl.append(image)

# %%
len(legit_anns_animl), len(legit_images_animl)
# Out:
# (52304, 52304)

# %%
len(animl['annotations']), len(animl['images'])
# Out:
# (52404, 51226)

# %%
for annotation in legit_anns:
    if annotation['category_id'] == 2: # fox
        annotation['category_id'] = 5 # fox
    elif annotation['category_id'] == 3: # skunk
        annotation['category_id'] = 15 # skunk
    elif annotation['category_id'] == 4: # rodent
        annotation['category_id'] = 19 # rodent

# %%
df = pd.DataFrame(legit_anns)

counts = df.groupby(['category_id']).size().reset_index(name='counts')

# mapping the category_id to the category name
counts['category_name'] = counts['category_id'].map(animl_map)
counts
# Out:
#    category_id  counts category_name
# 0            5   48120           fox
# 1           15    1071         skunk
# 2           19   82899        rodent

# %%
coco_data = {}
coco_data['images'] = legit_images + legit_images_animl
coco_data['annotations'] = legit_anns + legit_anns_animl
coco_data['categories'] = animl['categories']
coco_data['info'] = animl['info']

# %%
assert len(coco_data['images']) == len(legit_images) + len(legit_images_animl)

# %%
len(legit_images) + len(legit_images_animl)
# Out:
# 184394

# %%
len(coco_data['images'])
# Out:
# 184394

# %%
#with open('classifier-training/mdcache/v5.0b/mirav2_dataset.json', 'w') as f:
#    json.dump(coco_data, f)

# %%
#with open('classifier-training/mdcache/v5.0b/mirav2_dataset.json', 'r') as f:
#    d = json.load(f)

# %%
python animl-ml/classification/utils/cct_to_md.py \
  --input_filename ~/classifier-training/mdcache/v5.0b/mirav2_dataset.json \
  --output_filename ~/classifier-training/mdcache/v5.0b/mirav2_dataset_md.json

# %%
python animl-ml/classification/utils/crop_detections.py \
    ~/classifier-training/mdcache/v5.0b/mirav2_dataset_md.json \
    ~/crops/mirav2_dataset \
    --images-dir ~/images/mirav2_dataset \
    --threshold 0 --square-crops \
    --threads 50 \
    --logdir $BASE_LOGDIR
"""remember to change the dataset_name"""

# %% [markdown]
# There are only 1817 images failed to download or crop.

# %%
python ~/animl-ml/classification/utils/md_to_queried_images.py \
  --input_filename ~/classifier-training/mdcache/v5.0b/mirav2_dataset_md.json \
  --dataset mirav2_dataset \
  --output_filename $BASE_LOGDIR/queried_images.json

# %%
python CameraTraps/classification/create_classification_dataset.py \
    $BASE_LOGDIR \
    --mode csv splits \
    --queried-images-json $BASE_LOGDIR/queried_images.json \
    --cropped-images-dir ~/crops/ \
    --detector-output-cache-dir ~/classifier-training/mdcache --detector-version 5.0b \
    --threshold 0 \
    --min-locs 3 \
    --val-frac 0.2 \
    --test-frac 0.2 \
    --method random

# %%
python CameraTraps/classification/train_classifier.py \
    $BASE_LOGDIR \
    ~/crops \
    --model-name efficientnet-b3 --pretrained \
    --label-weighted \
    --epochs 50 --batch-size 80 --lr 3e-5 \ # I set batch-size 80 because 
    --weight-decay 1e-6 \
    --num-workers 4 \ 
    --logdir $BASE_LOGDIR --log-extreme-examples 3

# %%
49330 + 240459

# %%
tensorboard --logdir run --bind_all --samples_per_plugin scalars=0,images=0

# %%
python animl-ml/classification/utils/cct_to_md.py \
  --input_filename ~/classifier-training/mdcache/v5.0b/mirav2_rat.json \
  --output_filename ~/classifier-training/mdcache/v5.0b/mirav2_rat_md.json

# %% [markdown]
# ### Island Conservation Dataset

# %%
# Load the annotation data
with open('images/island/metadata/island_conservation.json', 'r') as f:
    island = json.load(f)

# %%
island_map = {island['categories'][i]['id']:island['categories'][i]['name'] for i in range(len(island['categories']))}

# %%
df = pd.DataFrame(island['annotations'])

counts = df.groupby(['category_id']).size().reset_index(name='counts')

# mapping the category_id to the category name
counts['category_name'] = counts['category_id'].map(island_map)
counts
# Out:
#     category_id  counts               category_name
# 0             0   77670                       empty
# 1             1     150                         cow
# 2             2     845                      donkey
# 3             3    6284                      iguana
# 4             4     967                       raven
# 5             5    4737                         cat
# 6             6     160                         dog
# 7             7   16338                         rat
# 8             8    6237                       human
# 9             9     967                     unknown
# 10           10     232           white-winged_dove
# 11           11     147                        bird
# 12           12      38                   passerine
# 13           13       1                         owl
# 14           14       6               burrowing_owl
# 15           15       1                  barred_owl
# 16           16       6                 green_heron
# 17           17       9            american_kestrel
# 18           18       3                 mockingbird
# 19           19       9            great_blue_heron
# 20           20     266                     chicken
# 21           21    6999                      petrel
# 22           22    8556                      rabbit
# 23           23    1099                petrel_chick
# 24           24     358                   eye_shine
# 25           25       7                     kestrel
# 26           26    2220                  shearwater
# 27           27     201                       coati
# 28           28      12                storm_petrel
# 29           29      30                      pigeon
# 30           30       1                        dove
# 31           31       5                      spider
# 32           32     278             short-eared_owl
# 33           33      40                      insect
# 34           34      15                      zorzal
# 35           35      15                        seal
# 36           36    3033                        goat
# 37           37    2588                         pig
# 38           38     113  yellow-crowned_night_heron
# 39           39       6                  sea_turtle
# 40           40     704                     rooster
# 41           41      20                        crab
# 42           42     334                    megapode
# 43           43     106                 brown_noddy
# 44           44      10              nicobar_pigeon
# 45           45      52                        rail
# 46           46     365              monitor_lizard
# 47           47       1                        moth
# 48           48     100                 hermit_crab

# %%
image_lookup = {img['id']: img for img in island['images']}
legit_anns_island = []
legit_images_island = []
for annotation in island['annotations']:
    image_id = annotation['image_id']
    image = image_lookup.get(image_id)
    if image is not None:
        if ((bbox := annotation.get('bbox')) is not None) and (annotation.get('category_id') in {7}):
            width, height = image['width'], image['height']
            if bbox[2] < 0.95 * width or bbox[3] < 0.95 * height:
                # print(annotation)
                legit_anns_island.append(annotation)
                # print(image)
                legit_images_island.append(image)

# %%
len(legit_anns_island), len(legit_images_island)
# Out:
# (16338, 16338)

# %% [markdown]
# There are 123,000 camera trap images from 123 camera locations from 7 islands in 6 countries

# %%
from collections import Counter
paths = []
countries = []
for img in legit_images_island:
    path = img['file_name'].split('/')[0:2]
    countries.append(img['file_name'].split('/')[0])
    paths.append('/'.join(path))
count_camera = Counter(paths)
count_countries = Counter(countries)

# %%
count_countries = count_countries.items()

# %%
data = dict(count_countries)
df = pd.DataFrame.from_dict(data,orient='index', columns=['count'])
print(f'There are in total 16338 rats.')
df
# Out:
# There are in total 16338 rats.
#                    count
# dominicanrepublic    207
# ecuador1               5
# chile                 24
# puertorico            52
# palau               2681
# ecuador2              45
# micronesia         13324

# %%
animl['images'][0]
# Out:
# {'id': '3422ea65783a5775971eec489105eebe',
#  'file_name': 'p_000020.jpg',
#  'original_relative_path': 'X811459F/p_000020_3422ea65783a5775971eec489105eebe.jpg',
#  'datetime': '2021-04-03T04:44:20.000Z',
#  'location': 'Walnut drainage',
#  'width': 2048,
#  'height': 1536}

# %%
for img in legit_images_island:
    path = img['file_name'].split('/')[0:2]
    path = '/'.join(path)
    img['location'] = path

# %%
for img in legit_images_island:
    img['original_relative_path'] = img['file_name']

# %%
legit_images_island[0]
# Out:
# {'id': 'dominicanrepublic_camara116_cam11618mayo2017b_dominicanrepublic_cam11618mayo2017b_20170126_033638_img_0090',
#  'file_name': 'dominicanrepublic/camara116/cam11618mayo2017b/dominicanrepublic_cam11618mayo2017b_20170126_033638_img_0090.jpg',
#  'width': 1920,
#  'height': 1080,
#  'location': 'dominicanrepublic/camara116',
#  'original_relative_path': 'dominicanrepublic/camara116/cam11618mayo2017b/dominicanrepublic_cam11618mayo2017b_20170126_033638_img_0090.jpg'}

# %%
for annotation in legit_anns_island:
    annotation['category_id'] = 22 # rat # change the id as same as animl's categories_id

# %%
legit_anns_island[0]
# Out:
# {'id': '6e80a662-df2b-11ea-820f-000d3a74c7de',
#  'image_id': 'dominicanrepublic_camara116_cam11618mayo2017b_dominicanrepublic_cam11618mayo2017b_20170126_033638_img_0090',
#  'category_id': 22,
#  'bbox': [982.0799999999999, 620.028, 294.912, 74.952]}

# %%
coco_data = {}
coco_data['images'] = legit_images + legit_images_animl + legit_images_island
coco_data['annotations'] = legit_anns + legit_anns_animl + legit_anns_island
coco_data['categories'] = animl['categories']
coco_data['info'] = animl['info']

# %%
assert len(coco_data['images']) == len(legit_images) + len(legit_images_animl) + len(legit_images_island)

# %%
assert len(coco_data['annotations']) == len(legit_anns) + len(legit_anns_animl) + len(legit_anns_island)

# %%
with open('mirav2_rat.json', 'w') as f:
    json.dump(coco_data, f)

# %%
with open('mirav2_rat.json', 'r') as f:
    mirav2_rat = json.load(f)

# %%
python animl-ml/classification/utils/cct_to_md.py \
  --input_filename ~/classifier-training/mdcache/v5.0b/mirav2_rat.json \
  --output_filename ~/classifier-training/mdcache/v5.0b/mirav2_rat_md.json

# %%
legit_anns_island
# Out:
# [{'id': '6e80a662-df2b-11ea-820f-000d3a74c7de',
#   'image_id': 'dominicanrepublic_camara116_cam11618mayo2017b_dominicanrepublic_cam11618mayo2017b_20170126_033638_img_0090',
#   'category_id': 22,
#   'bbox': [982.0799999999999, 620.028, 294.912, 74.952]},
#  {'id': '6f73518c-df2b-11ea-96fa-000d3a74c7de',
#   'image_id': 'dominicanrepublic_camara107_cam10701agosto2017_dominicanrepublic_cam10701agosto2017_20161227_041818_img_0047',
#   'category_id': 22,
#   'bbox': [1127.04, 628.02, 273.024, 126.036]},
#  {'id': '765fbb18-df2b-11ea-8df1-000d3a74c7de',
#   'image_id': 'dominicanrepublic_camara107_cam10717mayo2017_dominicanrepublic_cam10717mayo2017_20170401_035602_img_0039',
#   'category_id': 22,
#   'bbox': [521.088, 560.952, 364.032, 108.0]},
#  {'id': '76d67240-df2b-11ea-85b9-000d3a74c7de',
#   'image_id': 'dominicanrepublic_camara107_cam10701agosto2017_dominicanrepublic_cam10701agosto2017_20170125_032728_img_0113',
#   'category_id': 22,
#   'bbox': [769.9200000000001, 540.972, 294.912, 131.976]},
#  {'id': '77ad4b06-df2b-11ea-9416-000d3a74c7de',
#   'image_id': 'dominicanrepublic_camara106_cam10618mayo2017_dominicanrepublic_cam10618mayo2017_20161116_003221_img_0166',
#   'category_id': 22,
#   'bbox': [1246.08, 571.968, 510.91200000000003, 196.99200000000002]},
#  {'id': '80369ec0-df2b-11ea-a197-000d3a74c7de',
#   'image_id': 'dominicanrepublic_camara107_cam10701agosto2017_dominicanrepublic_cam10701agosto2017_20170126_041059_img_0123',
#   'category_id': 22,
#   'bbox': [1320.9599999999998, 597.996, 205.056, 100.98]},
#  {'id': '82f9e74c-df2b-11ea-a75e-000d3a74c7de',
#   'image_id': 'dominicanrepublic_camara107_cam10701agosto2017_dominicanrepublic_cam10701agosto2017_20170103_062806_img_0074',
#   'category_id': 22,
#   'bbox': [1190.016, 574.02, 258.048, 96.98400000000001]},
#  {'id': '83072dc8-df2b-11ea-96d8-000d3a74c7de',
#   'image_id': 'dominicanrepublic_camara107_cam10717mayo2017_dominicanrepublic_cam10717mayo2017_20170320_234438_img_0007',
#   'category_id': 22,
#   'bbox': [865.9200000000001, 555.0120000000001, 337.91999999999996, 89.964]},
#  {'id': '844a4bf6-df2b-11ea-a3c6-000d3a74c7de',
#   'image_id': 'dominicanrepublic_camara20_cam2026julio2015_dominicanrepublic_cam2026julio2015_20150720_060454_img_0044',
#   'category_id': 22,
#   'bbox': [0, 340.95599999999996, 259.008, 389.016]},
#  {'id': '844cbd08-df2b-11ea-9ed5-000d3a74c7de',
#   'image_id': 'dominicanrepublic_camara20_cam2026junio2015_dominicanrepublic_cam2026junio2015_20150516_042540_img_0026',
#   'category_id': 22,
#   'bbox': [628.992, 366.984, 240.0, 122.04]},
#  {'id': '89840c30-df2b-11ea-8ef9-000d3a74c7de',
#   'image_id': 'dominicanrepublic_camara115_cam11518mayo2017a_dominicanrepublic_cam11518mayo2017a_20170222_062908_img_0299',
#   'category_id': 22,
#   'bbox': [1371.072, 421.956, 102.912, 83.05199999999999]},
#  {'id': '898851d2-df2b-11ea-8af2-000d3a74c7de',
#   'image_id': 'dominicanrepublic_camara115_cam11518mayo2017a_dominicanrepublic_cam11518mayo2017a_20170301_010215_img_0325',
#   'category_id': 22,
#   'bbox': [318.912, 478.98, 100.032, 81.972]},
#  {'id': '89d07eb0-df2b-11ea-a156-000d3a74c7de',
#   'image_id': 'dominicanrepublic_camara12_cam1225septiembre2015_dominicanrepublic_cam1225septiembre2015_20150915_191217_img_0269',
#   'category_id': 22,
#   'bbox': [200.064, 408.024, 402.048, 81.0]},
#  {'id': '8b29d086-df2b-11ea-92b2-000d3a74c7de',
#   'image_id': 'dominicanrepublic_camara32_cam3220julio2016_dominicanrepublic_cam3220julio2016_20160716_023604_img_0150',
#   'category_id': 22,
#   'bbox': [1772.9279999999999, 984.96, 148.032, 46.98]},
#  {'id': '8b42fddd-df2b-11ea-a074-000d3a74c7de',
#   'image_id': 'dominicanrepublic_cam
000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181022_004709_rcnx0836',
#   'category_id': 22,
#   'bbox': [336.0768, 871.056, 569.9584, 344.016]},
#  {'id': '3709a7ac-df31-11ea-91cd-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181028_203953_rcnx0870',
#   'category_id': 22,
#   'bbox': [215.04, 873.936, 644.096, 271.008]},
#  {'id': '370b8ef0-df31-11ea-9611-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181029_225746_rcnx0887',
#   'category_id': 22,
#   'bbox': [1045.0944, 1153.008, 442.9824, 250.99200000000002]},
#  {'id': '370dd8e4-df31-11ea-a4d1-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181029_225746_rcnx0888',
#   'category_id': 22,
#   'bbox': [1170.0224, 1088.9279999999999, 830.0544, 322.992]},
#  {'id': '370fadae-df31-11ea-9ac3-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181029_233011_rcnx0895',
#   'category_id': 22,
#   'bbox': [382.976, 1214.0639999999999, 353.0752, 182.01600000000002]},
#  {'id': '372266a4-df31-11ea-8040-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181112_091451_rcnx0996',
#   'category_id': 22,
#   'bbox': [583.0656, 796.0319999999999, 232.0384, 182.01600000000002]},
#  {'id': '37244080-df31-11ea-a316-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181112_091452_rcnx0997',
#   'category_id': 22,
#   'bbox': [595.968, 795.024, 218.9312, 167.04000000000002]},
#  {'id': '3726b18a-df31-11ea-b4fe-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181117_015749_rcnx1023',
#   'category_id': 22,
#   'bbox': [763.904, 934.992, 287.9488, 281.952]},
#  {'id': '3728b4fe-df31-11ea-ad7d-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181117_015750_rcnx1025',
#   'category_id': 22,
#   'bbox': [764.928, 945.936, 288.9728, 285.984]},
#  {'id': '372afec2-df31-11ea-a4e7-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181121_203927_rcnx1046',
#   'category_id': 22,
#   'bbox': [647.9872, 1088.064, 517.9392, 224.064]},
#  {'id': '373a1ed8-df31-11ea-975f-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181127_184727_rcnx1089',
#   'category_id': 22,
#   'bbox': [910.9504, 1244.016, 368.0256, 163.00799999999998]},
#  {'id': '373dde4a-df31-11ea-b131-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181206_031640_rcnx1135',
#   'category_id': 22,
#   'bbox': [712.9088, 1015.0559999999999, 208.0768, 360.0]},
#  {'id': '373fe3b6-df31-11ea-9edd-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181208_233749_rcnx1146',
#   'category_id': 22,
#   'bbox': [407.9616, 670.032, 312.9344, 192.96]},
#  {'id': '3741df8a-df31-11ea-b48b-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181208_233750_rcnx1148',
#   'category_id': 22,
#   'bbox': [352.0512, 649.008, 336.0768, 195.984]},
#  {'id': '374407c0-df31-11ea-8936-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181209_004256_rcnx1163',
#   'category_id': 22,
#   'bbox': [3.072, 934.992, 595.968, 286.992]},
#  {'id': '37465fcc-df31-11ea-8f29-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181209_022315_rcnx1172',
#   'category_id': 22,
#   'bbox': [647.9872, 1238.976, 540.0576, 167.04000000000002]},
#  {'id': '3748c918-df31-11ea-b492-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181209_022316_rcnx1173',
#   'category_id': 22,
#   'bbox': [721.92, 1128.96, 304.9472, 277.056]},
#  {'id': '374b4524-df31-11ea-9952-000d3a74c7de',
#   'image_id': 'palau_cam01a_cam1a12122018_palau_cam1a12122018_20181209_023244_rcnx1182',
#   'category_id': 22,
#   'bbox': [765.952, 770.976, 142.9504, 440.92800000000005]},
#  ...]

# %%
with open('check.json','w') as f:
    json.write(legit_anns_island)
